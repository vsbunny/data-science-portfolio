# %%
import pandas as pd # Import pandas for data manipulation and DataFrame operations
import glob # Import glob for finding files matching a pattern (e.g., all CSVs in a directory)
import os # Import os for operating system-related functionalities (e.g., path manipulation)

# --- Configuration ---
# Define the path to the directory containing the extracted CSV files from the scraper.
# It's assumed these CSVs are the raw output from the QS World Rankings scraper.
# IMPORTANT: Replace 'path to extracted csv files' with the actual relative or absolute path
path = '/Scraping_projects/QS_world_rankings'
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /Users/vsbunny/Documents/Python Projects/scraping_projects/world_rankings/QS World Rankings

# %%
# --- Configuration ---
# Define the path to the directory containing your raw extracted CSV files.
# This path is relative to where this script (process_rankings.py) is located.
# Assumed structure: .../QS_world_rankings/QS World Rankings/
CSV_INPUT_FOLDER = 'rankings_csv'

# Define the output folder for the combined and processed CSVs.
# This folder will be created within the same directory as this script.
COMBINED_OUTPUT_FOLDER = 'Combined_Rankings'

# Create the output folder if it doesn't exist
if not os.path.exists(COMBINED_OUTPUT_FOLDER):
    os.makedirs(COMBINED_OUTPUT_FOLDER)
    print(f"Created output directory for combined CSVs: {COMBINED_OUTPUT_FOLDER}")


# --- Define the mapping for Child Subject to Parent Subject ---
# This dictionary maps specific child subject strings (extracted from filenames)
# to their broader parent subject categories. This helps standardize the data.
# IMPORTANT: This map contains only a subset for demonstration. It is needed to
# populate this dictionary with ALL the relevant child subjects and their
# corresponding parent categories if you expand the scraping.
subject_to_parent_map = {
    "theology-divinity-religious-studies": "Arts & Humanities",
    #"veterinary-science": "Life Sciences & Medicine",
    #"computer-science": "Engineering & Technology",
    #"physics-astronomy": "Natural Sciences",
    "economics-econometrics": "Social Sciences & Management",
    "accounting-finance": "Social Sciences & Management",
    "business-management-studies": "Social Sciences & Management",
    "arts-and-humanities": "Arts & Humanities",
    "archaeology" : "Arts & Humanities", 
    #"life-sciences-medicine": "Life Sciences & Medicine",
    #"natural-sciences": "Natural Sciences",
    #"social-sciences-management": "Social Sciences & Management",
    # Add the rest of the child subjects and their parent categories here as needed:
    # "mathematics": "Natural Sciences",
     "history": "Arts & Humanities",
    # ... and so on for all subjects the scraper might extract.
}
print("Subject-to-Parent mapping defined (partial for demonstration).")

# --- File Discovery ---
# Use glob to find all files ending with '.csv' within the specified input folder.
# os.path.join ensures cross-platform compatibility when constructing paths.
all_files = glob.glob(os.path.join(CSV_INPUT_FOLDER, "*.csv"))
print(f"Found CSV files: {all_files}")

# Use a dictionary to store DataFrames, organized by year.
# This structure facilitates combining all subject-specific CSVs for a given year.
dfs_by_year = {}

# --- Process Each CSV File ---
# Iterate through each found CSV file to read, clean, and standardize its data.
for filepath in all_files:
    try:
        # Extract only the filename from the full path (e.g., 'QS_Rankings_subject-name-year.csv').
        filename = os.path.basename(filepath)
        print(f"\nProcessing file: {filename}")

        # Split the filename by underscores to parse out components.
        # Assumed filename format: 'QS_Rankings_SUBJECT-YEAR.csv'
        parts = filename.split('_')
        # Extract the subject and year from the last part of the filename.
        # .split('.')[0] removes the '.csv' extension.
        # .rsplit('-', 1) splits from the right, only once, to separate the subject name from the year.
        subject_and_year = parts[-1].split('.')[0]
        subject, year = subject_and_year.rsplit('-', 1)

        # Read the CSV file into a Pandas DataFrame.
        df = pd.read_csv(filepath)
        print(f"DataFrame loaded. Original columns: {df.columns.tolist()}")

        # --- Data Standardization and Feature Addition Logic ---
        # This section handles variations in the raw scraped data (e.g., missing 'Global Engagement' column)
        # and adds new categorical features ('Year', 'Parent Subject', 'Child Subject') to standardize the dataset.

        # 1. Ensure 'Global Engagement' column exists for consistent schema.
        if 'Global Engagement' not in df.columns:
            # If 'Global Engagement' is NOT present, add it as an empty column.
            # This accounts for variations in data provided by the website for certain subjects/years.
            df['Global Engagement'] = '' # Initialize with empty strings
            print("Added 'Global Engagement' column (was missing in this file).")

        # Dynamically assign 'Parent Subject' using the pre-defined mapping dictionary.
        # .get(key, default_value) provides a robust lookup, returning "Uncategorized" if a subject is not mapped.
        parent_subject_category = subject_to_parent_map.get(subject, "Uncategorized")
        print(f"Assigned Parent Subject: '{parent_subject_category}' for Child Subject: '{subject}'")

        # Determine the insertion index for new columns to maintain consistent order.
        # Defaults to -1 (end of DataFrame) if 'Global Engagement' column is not found (though it should be handled above).
        global_engagement_index = -1
        if 'Global Engagement' in df.columns:
            global_engagement_index = df.columns.get_loc('Global Engagement')

        # Insert 'Year', 'Parent Subject', and 'Child Subject' columns into the DataFrame.
        # These are inserted relative to the 'Global Engagement' column for standardized placement.
        df.insert(global_engagement_index + 1, 'Year', year)
        df.insert(global_engagement_index + 2, 'Parent Subject', parent_subject_category)
        df.insert(global_engagement_index + 3, 'Child Subject', subject)
        print("Inserted 'Year', 'Parent Subject', 'Child Subject' columns.")


        # --- Grouping DataFrames by Year ---
        # Store the processed DataFrame in the 'dfs_by_year' dictionary, grouped by its 'year'.
        if year not in dfs_by_year:
            dfs_by_year[year] = [] # Initialize a list for the year if it's encountered for the first time
        dfs_by_year[year].append(df) # Add the processed DataFrame to the list for its respective year

    except ValueError as e:
        # Catch ValueError, which might occur if filename parsing fails due to an unexpected format.
        print(f"Skipping file with unexpected name or format: {filepath}. Error: {e}")
        continue # Continue processing the next file in the list
    except KeyError as e:
        # Catch KeyError if a 'child subject' extracted from the filename is not found in the 'subject_to_parent_map'.
        print(f"Skipping file: '{filepath}'. Child subject '{subject}' not found in mapping. Error: {e}")
        continue # Continue processing the next file

# --- Combine and Save DataFrames by Year ---
# After processing all individual CSVs, this section combines them into a single DataFrame for each year.
# This creates a consolidated dataset per year, ready for further analysis or model training.
print("\nCombining and saving data by year...")
for year, dfs in dfs_by_year.items():
    # Concatenate all DataFrames for the current year into a single DataFrame.
    # ignore_index=True resets the index of the combined DataFrame, preventing duplicate indices.
    combined_df = pd.concat(dfs, ignore_index=True)

    # --- Optional: Reorder columns for final output consistency ---
    # This ensures a standardized column order across all combined CSVs, which is beneficial for
    # subsequent analysis and readability. Adjust 'desired_order' to your preferred final sequence.
    desired_order = [
        'Rank', 'Name', 'Location', 'Parent Subject', 'Child Subject', 'Year',
        'Employer Reputation', 'H-index Citations', 'Citations per Paper',
        'Academic Reputation', 'Global Engagement'
    ]
    # Filter and reorder columns, adding any new columns found in 'combined_df' that aren't in 'desired_order'
    # (these remaining columns will be appended at the end, sorted alphabetically).
    final_columns = [col for col in desired_order if col in combined_df.columns]
    remaining_columns = [col for col in combined_df.columns if col not in set(final_columns)]
    combined_df = combined_df[final_columns + sorted(remaining_columns)] # Reorder and append sorted remaining columns


    # Save the combined DataFrame for the year to a new CSV file.
    # The output file is placed in the 'COMBINED_OUTPUT_FOLDER' (e.g., './Combined_Rankings/').
    # index=False prevents pandas from writing the DataFrame index as a column in the CSV.
    output_filename = f'QS_Rankings_Combined_{year}.csv'
    output_filepath = os.path.join(COMBINED_OUTPUT_FOLDER, output_filename)
    combined_df.to_csv(output_filepath, index=False)
    print(f"Saved combined data for {year} to: {output_filepath}")

print("\nData wrangling complete. Combined CSVs are in the 'Combined_Rankings' folder.")
# Out:
# Subject-to-Parent mapping defined (partial for demonstration).
# Found CSV files: ['rankings_csv/QS_Rankings_art-design-2023.csv', 'rankings_csv/QS_Rankings_economics-econometrics-2022.csv', 'rankings_csv/QS_Rankings_classics-ancient-history-2024.csv', 'rankings_csv/QS_Rankings_economics-econometrics-2023.csv', 'rankings_csv/QS_Rankings_art-design-2022.csv', 'rankings_csv/QS_Rankings_communication-media-studies-2024.csv', 'rankings_csv/QS_Rankings_art-history-2024.csv', 'rankings_csv/QS_Rankings_art-design-2020.csv', 'rankings_csv/QS_Rankings_economics-econometrics-2021.csv', 'rankings_csv/QS_Rankings_linguistics-2024.csv', 'rankings_csv/QS_Rankings_marketing-2023.csv', 'rankings_csv/QS_Rankings_economics-econometrics-2020.csv', 'rankings_csv/QS_Rankings_art-design-2021.csv', 'rankings_csv/QS_Rankings_communication-media-studies-2023.csv', 'rankings_csv/QS_Rankings_economics-econometrics-2024.csv', 'rankings_csv/QS_Rankings_linguistics-2021.csv', 'rankings_csv/QS_Rankings_classics-ancient-history-2023.csv', 'rankings_csv/QS_Rankings_classics-ancient-history-2022.csv', 'rankings_csv/QS_Rankings_linguistics-2020.csv', 'rankings_csv/QS_Rankings_art-design-2024.csv', 'rankings_csv/QS_Rankings_communication-media-studies-2022.csv', 'rankings_csv/QS_Rankings_communication-media-studies-2020.csv', 'rankings_csv/QS_Rankings_linguistics-2022.csv', 'rankings_csv/QS_Rankings_classics-ancient-history-2020.csv', 'rankings_csv/QS_Rankings_marketing-2024.csv', 'rankings_csv/QS_Rankings_classics-ancient-history-2021.csv', 'rankings_csv/QS_Rankings_linguistics-2023.csv', 'rankings_csv/QS_Rankings_communication-media-studies-2021.csv', 'rankings_csv/QS_Rankings_art-history-2023.csv', 'rankings_csv/QS_Rankings_history-2023.csv', 'rankings_csv/QS_Rankings_anthropology-2021.csv', 'rankings_csv/QS_Rankings_anthropology-2020.csv', 'rankings_csv/QS_Rankings_history-2022.csv', 'rankings_csv/QS_Rankings_history-2020.csv', 'rankings_csv/QS_Rankings_anthropology-2022.csv', 'rankings_csv/QS_Rankings_anthropology-2023.csv', 'rankings_csv/QS_Rankings_history-2021.csv', 'rankings_csv/QS_Rankings_architecture-built-environment-2024.csv', 'rankings_csv/QS_Rankings_architecture-built-environment-2020.csv', 'rankings_csv/QS_Rankings_history-2024.csv', 'rankings_csv/QS_Rankings_architecture-built-environment-2021.csv', 'rankings_csv/QS_Rankings_architecture-built-environment-2023.csv', 'rankings_csv/QS_Rankings_music-2024.csv', 'rankings_csv/QS_Rankings_anthropology-2024.csv', 'rankings_csv/QS_Rankings_architecture-built-environment-2022.csv', 'rankings_csv/QS_Rankings_social-policy-administration-2020.csv', 'rankings_csv/QS_Rankings_sociology-2024.csv', 'rankings_csv/QS_Rankings_archaeology-2021.csv', 'rankings_csv/QS_Rankings_library-information-management-2021.csv', 'rankings_csv/QS_Rankings_theology-divinity-religious-studies-2021.csv', 'rankings_csv/QS_Rankings_theology-divinity-religious-studies-2020.csv', 'rankings_csv/QS_Rankings_library-information-management-2020.csv', 'rankings_csv/QS_Rankings_archaeology-2020.csv', 'rankings_csv/QS_Rankings_social-policy-administration-2021.csv', 'rankings_csv/QS_Rankings_social-policy-administration-2023.csv', 'rankings_csv/QS_Rankings_archaeology-2022.csv', 'rankings_csv/QS_Rankings_library-information-management-2022.csv', 'rankings_csv/QS_Rankings_theology-divinity-religious-studies-2022.csv', 'rankings_csv/QS_Rankings_law-legal-studies-2024.csv', 'rankings_csv/QS_Rankings_theology-divinity-religious-studies-2023.csv', 'rankings_csv/QS_Rankings_library-information-management-2023.csv', 'rankings_csv/QS_Rankings_archaeology-2023.csv', 'rankings_csv/QS_Rankings_social-policy-administration-2022.csv', 'rankings_csv/QS_Rankings_sociology-2022.csv', 'rankings_csv/QS_Rankings_law-legal-studies-2021.csv', 'rankings_csv/QS_Rankings_law-legal-studies-2020.csv', 'rankings_csv/QS_Rankings_sociology-2023.csv', 'rankings_csv/QS_Rankings_archaeology-2024.csv', 'rankings_csv/QS_Rankings_sociology-2021.csv', 'rankings_csv/QS_Rankings_library-information-management-2024.csv', 'rankings_csv/QS_R ...
#
# Processing file: QS_Rankings_art-design-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-design'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_economics-econometrics-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'economics-econometrics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_classics-ancient-history-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'classics-ancient-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_economics-econometrics-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'economics-econometrics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_art-design-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-design'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_communication-media-studies-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'communication-media-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_art-history-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_art-design-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-design'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_economics-econometrics-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'economics-econometrics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_linguistics-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'linguistics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_marketing-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'marketing'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_economics-econometrics-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'economics-econometrics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_art-design-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-design'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_communication-media-studies-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'communication-media-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_economics-econometrics-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'economics-econometrics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_linguistics-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'linguistics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_classics-ancient-history-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'classics-ancient-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_classics-ancient-history-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'classics-ancient-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_linguistics-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'linguistics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_art-design-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-design'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_communication-media-studies-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'communication-media-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_communication-media-studies-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'communication-media-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_linguistics-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'linguistics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_classics-ancient-history-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'classics-ancient-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_marketing-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'marketing'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_classics-ancient-history-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'classics-ancient-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_linguistics-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'linguistics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_communication-media-studies-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'communication-media-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_art-history-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'art-history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_history-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_anthropology-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'anthropology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_anthropology-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'anthropology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_history-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_history-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_anthropology-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'anthropology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_anthropology-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'anthropology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_history-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_architecture-built-environment-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'architecture-built-environment'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_architecture-built-environment-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'architecture-built-environment'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_history-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'history'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_architecture-built-environment-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'architecture-built-environment'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_architecture-built-environment-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'architecture-built-environment'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_music-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'music'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_anthropology-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'anthropology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_architecture-built-environment-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'architecture-built-environment'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_social-policy-administration-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'social-policy-administration'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sociology-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sociology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_archaeology-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'archaeology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_library-information-management-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'library-information-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_theology-divinity-religious-studies-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'theology-divinity-religious-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_theology-divinity-religious-studies-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'theology-divinity-religious-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_library-information-management-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'library-information-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_archaeology-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'archaeology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_social-policy-administration-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'social-policy-administration'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_social-policy-administration-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'social-policy-administration'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_archaeology-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'archaeology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_library-information-management-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'library-information-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_theology-divinity-religious-studies-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'theology-divinity-religious-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_law-legal-studies-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'law-legal-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_theology-divinity-religious-studies-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'theology-divinity-religious-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_library-information-management-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'library-information-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_archaeology-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'archaeology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_social-policy-administration-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'social-policy-administration'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sociology-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sociology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_law-legal-studies-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'law-legal-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_law-legal-studies-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'law-legal-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sociology-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sociology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_archaeology-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'archaeology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sociology-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sociology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_library-information-management-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'library-information-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_theology-divinity-religious-studies-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Arts & Humanities' for Child Subject: 'theology-divinity-religious-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_law-legal-studies-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'law-legal-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_law-legal-studies-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'law-legal-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sociology-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sociology'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_social-policy-administration-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'social-policy-administration'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_education-training-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'education-training'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_philosophy-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'philosophy'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_accounting-finance-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'accounting-finance'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_modern-languages-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'modern-languages'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_politics-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'politics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_development-studies-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'development-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_hospitality-leisure-management-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'hospitality-leisure-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sports-related-subjects-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sports-related-subjects'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_development-studies-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'development-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_politics-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'politics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_english-language-literature-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'english-language-literature'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_modern-languages-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'modern-languages'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_accounting-finance-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'accounting-finance'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_philosophy-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'philosophy'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_philosophy-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'philosophy'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_accounting-finance-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'accounting-finance'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_statistics-operational-research-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'statistics-operational-research'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_modern-languages-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'modern-languages'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_politics-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'politics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_development-studies-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'development-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_business-management-studies-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'business-management-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_development-studies-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'development-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_performing-arts-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'performing-arts'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_politics-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'politics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_modern-languages-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'modern-languages'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_accounting-finance-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'accounting-finance'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_philosophy-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'philosophy'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_education-training-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'education-training'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_accounting-finance-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'accounting-finance'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_statistics-operational-research-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'statistics-operational-research'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_english-language-literature-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'english-language-literature'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_performing-arts-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'performing-arts'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_politics-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'politics'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_hospitality-leisure-management-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'hospitality-leisure-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sports-related-subjects-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sports-related-subjects'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_development-studies-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'development-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_business-management-studies-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'business-management-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_business-management-studies-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'business-management-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sports-related-subjects-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sports-related-subjects'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_hospitality-leisure-management-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'hospitality-leisure-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_performing-arts-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'performing-arts'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_english-language-literature-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'english-language-literature'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_statistics-operational-research-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'statistics-operational-research'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_philosophy-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'philosophy'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_education-training-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'education-training'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_education-training-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'education-training'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_modern-languages-2024.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'modern-languages'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_statistics-operational-research-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'statistics-operational-research'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_english-language-literature-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'english-language-literature'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_performing-arts-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'performing-arts'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_hospitality-leisure-management-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'hospitality-leisure-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sports-related-subjects-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sports-related-subjects'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_business-management-studies-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'business-management-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_business-management-studies-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Social Sciences & Management' for Child Subject: 'business-management-studies'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_sports-related-subjects-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'sports-related-subjects'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_hospitality-leisure-management-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'hospitality-leisure-management'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_performing-arts-2022.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'performing-arts'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_english-language-literature-2021.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'english-language-literature'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_statistics-operational-research-2023.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation', 'Global Engagement']
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'statistics-operational-research'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Processing file: QS_Rankings_education-training-2020.csv
# DataFrame loaded. Original columns: ['Rank', 'Name', 'Location', 'Employer Reputation', 'H-index Citations', 'Citations per Paper', 'Academic Reputation']
# Added 'Global Engagement' column (was missing in this file).
# Assigned Parent Subject: 'Uncategorized' for Child Subject: 'education-training'
# Inserted 'Year', 'Parent Subject', 'Child Subject' columns.
#
# Combining and saving data by year...
# Saved combined data for 2023 to: Combined_Rankings/QS_Rankings_Combined_2023.csv
# Saved combined data for 2022 to: Combined_Rankings/QS_Rankings_Combined_2022.csv
# Saved combined data for 2024 to: Combined_Rankings/QS_Rankings_Combined_2024.csv
# Saved combined data for 2020 to: Combined_Rankings/QS_Rankings_Combined_2020.csv
# Saved combined data for 2021 to: Combined_Rankings/QS_Rankings_Combined_2021.csv
#
# Data wrangling complete. Combined CSVs are in the 'Combined_Rankings' folder.
